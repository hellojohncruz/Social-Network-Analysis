# %%
import networkx as net
import matplotlib.pyplot as plt

# %%
org_chart = net.read_pajek("ACME_orgchart.net")
net.draw(org_chart)

# %%
advice = net.read_pajek("ACME_advice.net")
net.draw(advice)
